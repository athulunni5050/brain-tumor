# %% [markdown]
# <a href="https://colab.research.google.com/github/athulunni5050/brain-tumor/blob/main/Result.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import files
import keras
from keras import models
import cv2
import urllib
import requests
import time

while True:
  time.sleep(5)
  response =  requests.get('http://brain.wiooprojects.xyz/api.php')
  response.content
  if response.content == b'\n1':
    print("yes")
    resp = urllib.request.urlopen("http://brain.wiooprojects.xyz/uploads/image.jpg")
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)

    path = "http://brain.wiooprojects.xyz/image.jpg"
    my_model = models.load_model("/content/drive/MyDrive/Brain Tumor/my_model.h5")

    execfile('/content/drive/MyDrive/app.py')

    #my_model.summary()
    img_size=256
    img = cv2.imread(path)
    img = cv2.resize(image, (img_size,img_size))
    newimg = np.asarray(img)
    pixels = newimg.astype('float32')
    pixels /= 255.0
    print(pixels.shape)
    a = []
    a.append(pixels.tolist())
    arr = numpy.array(a)

    out = {0:'Glioma', 1:'Meningioma', 2:'No Tumor', 3:'Pituitary'}
    pred = my_model.predict(arr)
    Model_Predict = numpy.argmax(pred)
    Result = out[Model_Predict]
    app1 = app(Result)

    dec = " * * * * "
    print(dec*10, "\n Result = ",Result, "\n",app1,"\n\n" )
    result="\n Result = ",Result, "\n",app1,"\n\n" 
    response =  requests.get('http://brain.wiooprojects.xyz/api.php?result=' + str(Result)+'&msg='+str(app1))
    #cv2_imshow(img)
# Out:
# yes
# (256, 256, 3)
#  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *
#  Result =  No Tumor
#
#
#
# yes
# (256, 256, 3)
#  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *
#  Result =  Pituitary
#  Grade 3 : These tumors are more likely to have rapidly dividing cells but no dead cells. They can grow quickly.
#
#
# yes
# (256, 256, 3)
#  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *
#  Result =  Pituitary
#  Grade 2 : These tumors are less likely to grow and spread.
#
#
# yes
# (256, 256, 3)
#  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *
#  Result =  Meningioma
#  Grade 4 :  In a grade IV tumor, cells in the tumor are actively dividing.
#
#
# yes
# (256, 256, 3)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
resp = urllib.request.urlopen("http://brain.wiooprojects.xyz/uploads/image.jpg")
image = np.asarray(bytearray(resp.read()), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_COLOR)

path = "http://brain.wiooprojects.xyz/image.jpg"
my_model = models.load_model("/content/drive/MyDrive/Brain Tumor/my_model.h5")

execfile('/content/drive/MyDrive/app.py')

#my_model.summary()
img_size=256
img = cv2.imread(path)
img = cv2.resize(image, (img_size,img_size))
newimg = np.asarray(img)
pixels = newimg.astype('float32')
pixels /= 255.0
print(pixels.shape)
a = []
a.append(pixels.tolist())
arr = numpy.array(a)

out = {0:'Glioma', 1:'Meningioma', 2:'No Tumor', 3:'Pituitary'}
pred = my_model.predict(arr)
Model_Predict = numpy.argmax(pred)
Result = out[Model_Predict]
app1 = app(Result)

dec = " * * * * "
print(dec*10, "\n Result = ",Result, "\n",app1,"\n\n" )
result = "\n Result = ",Result, "\n",app1,"\n\n" 
cv2_imshow(img)

# %%
 
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-81b80ca8-cd39-4ae9-ac43-0c56317e1636" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-81b80ca8-cd39-4ae9-ac43-0c56317e1636">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving p (6).jpg to p (6).jpg
# User uploaded file "p (6).jpg" with length 33992 bytes

# %%
fn
# Out:
# 'p (6).jpg'

# %%
path = "/content/"+fn
my_model = models.load_model("/content/drive/MyDrive/Brain Tumor/my_model.h5")

execfile('/content/drive/MyDrive/app.py')

#my_model.summary()
img_size=256
img = cv2.imread(path)
img = cv2.resize(img, (img_size,img_size))
newimg = np.asarray(img)
pixels = newimg.astype('float32')
pixels /= 255.0
print(pixels.shape)
a = []
a.append(pixels.tolist())
arr = numpy.array(a)

out = {0:'Glioma', 1:'Meningioma', 2:'No Tumor', 3:'Pituitary'}
pred = my_model.predict(arr)
Model_Predict = numpy.argmax(pred)
Result = out[Model_Predict]
app1 = app(Result)

dec = " * * * * "
print(dec*10, "\n Result = ",Result, "\n",app1,"\n\n" )
cv2_imshow(img)
# Out:
# (256, 256, 3)
#  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *  * * * *
#  Result =  Pituitary
#  Grade 3 : These tumors are more likely to have rapidly dividing cells but no dead cells. They can grow quickly.
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FBEDE533910>
